# %%
from datasets import load_dataset
from huggingface_hub import login

from dotenv import load_dotenv
import os

load_dotenv()

hf_token = os.getenv("HF_TOKEN")

login(token=hf_token)
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %%
ds = load_dataset('ChaiJohn/TLD')
# Out:
# Repo card metadata block was not found. Setting CardData to empty.
# Cancellation requested; stopping current tasks.
# Cancellation requested; stopping current tasks.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /opt/anaconda3/envs/owl-vit/lib/python3.13/site-packages/huggingface_hub/file_download.py:626, in xet_get(incomplete_path, xet_file_data, headers, expected_size, displayed_filename, _tqdm_bar)
#     624     progress.update(progress_bytes)
# --> 626 download_files(
#     627     xet_download_info,
#     628     endpoint=connection_info.endpoint,
#     629     token_info=(connection_info.access_token, connection_info.expiration_unix_epoch),
#     630     token_refresher=token_refresher,
#     631     progress_updater=[progress_updater],
#     632 )
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# ...
